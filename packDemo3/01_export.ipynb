# %% [markdown]
# ## About
#
#
# * in that venv export asked for next versions:
# ```
# pip install model-compression-toolkit==2.1.1 sony-custom-layers==0.2.0 tensorflow==2.12.0
# ```

# %%
from ultralytics import YOLO

# Load a YOLOv8n PyTorch model
model = YOLO("yolov8n-face.pt")

# Export the model
model.export(format="imx", data="coco8.yaml")  # exports with PTQ quantization by default
# Out:
# WARNING ⚠️ yolov8n-face.pt appears to require 'omegaconf', which is not in Ultralytics requirements.
# AutoInstall will run now for 'omegaconf' but this feature will be removed in the future.
# Recommend fixes are to train a new model using the latest 'ultralytics' package or to run a command with an official Ultralytics model, i.e. 'yolo predict model=yolo11n.pt'
# requirements: Ultralytics requirement ['omegaconf'] not found, attempting AutoUpdate...
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 KB 1.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 KB 4.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144573 sha256=8a5dee02976e6782489f66e7c0e316deff30a17b3576d67a325e937fdb4b09ea
# ...

# %% [markdown]
# ## test

# %%
test_url = 'https://media.proprofs.com/images/QM/user_images/2503852/New%20Project%20(33)(288).jpg'

# %%
## show image
import requests
from PIL import Image
from io import BytesIO
import matplotlib.pyplot as plt
# Fetch the image via HTTP GET
response = requests.get(test_url)
# Open the image from the downloaded bytes
img = Image.open(BytesIO(response.content))
# Display using matplotlib
plt.imshow(img)
plt.axis('off')  # Hide axis labels
plt.show()

# %%
# Load the exported model
imx_model = YOLO("yolov8n-face_imx_model")

# Run inference
results = imx_model(test_url)
# Out:
# WARNING ⚠️ Unable to automatically guess model task, assuming 'task=detect'. Explicitly define task for your model, i.e. 'task=detect', 'segment', 'classify','pose' or 'obb'.
# Loading yolov8n-face_imx_model for ONNX Runtime inference...
# Using ONNX Runtime CPUExecutionProvider
# Loading yolov8n-face_imx_model/yolov8n-face_imx.onnx for ONNX IMX inference...
#
# ...
# 100%|██████████| 175k/175k [00:00<00:00, 1.24MB/s]
# image 1/1 /home/user/proj/imx500/kmGit/pack3/New Project (33)(288).jpg: 640x640 10 faces, 1802.8ms
# Speed: 1.2ms preprocess, 1802.8ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)

# %%
# 3. Display bounding boxes on image
annotated_image = results[0].plot()

# 4. (Optional) Show in notebook
import matplotlib.pyplot as plt

plt.imshow(annotated_image)
plt.axis("off")
plt.show()
