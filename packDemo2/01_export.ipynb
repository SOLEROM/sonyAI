# %% [markdown]
# ## About
#
#
# * in that venv export asked for next versions:
# ```
# pip install model-compression-toolkit==2.1.1 sony-custom-layers==0.2.0 tensorflow==2.12.0
# ```

# %%
from ultralytics import YOLO

# Load a YOLOv8n PyTorch model
model = YOLO("yolov8n.pt")

# Export the model
model.export(format="imx", data="coco8.yaml")  # exports with PTQ quantization by default
# Out:
# Ultralytics 8.3.82 🚀 Python-3.11.0rc1 torch-2.6.0+cu124 CPU (13th Gen Intel Core(TM) i5-1345U)
# WARNING ⚠️ IMX only supports int8 export, setting int8=True.
# YOLOv8n summary (fused): 72 layers, 3,151,904 parameters, 0 gradients, 8.7 GFLOPs
#
# PyTorch: starting from 'yolov8n.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) ((1, 8400, 4), (1, 8400, 80)) (6.2 MB)
#
# IMX: starting export with model_compression_toolkit 2.1.1...
# IMX: collecting INT8 calibration images from 'data=coco8.yaml'
# /home/user/proj/imx500/venvBuildImx500/lib/python3.11/site-packages/sony_custom_layers/pytorch/object_detection/nms.py:120: FutureWarning: `torch.library.impl_abstract` was renamed to `torch.library.register_fake`. Please use that instead; we will remove `torch.library.impl_abstract` in a future version of PyTorch.
#   @torch.library.impl_abstract(MULTICLASS_NMS_TORCH_OP_QUALNAME)
# Scanning /home/user/proj/imx500/myKM_readONLY/packDemo2/datasets/coco8/labels/val.cache... 4 images, 0 backgrounds, 0 corrupt: 100%|██████████| 4/4 [00:00<?, ?it/s]
# IMX: WARNING ⚠️ >300 images recommended for INT8 calibration, found 4 images.
# representative_data_gen generates a batch size of 1 which can be slow for optimization: consider increasing the batch size
# WARNING:Model Compression Toolkit:Pytorch model has a parameter or constant Tensor value. This can cause unexpected behaviour when converting the model.
# WARNING:Model Compression Toolkit:Pytorch model has a parameter or constant Tensor value. This can cause unexpected behaviour when converting the model.
# WARNING:Model Compression Toolkit:Pytorch model has a parameter or constant Tensor value. This can cause unexpected behaviour when converting the model.
# WARNING:Model Compression Toolkit:Pytorch model has a parameter or constant Tensor value. This can cause unexpected behaviour when converting the model.
# WARNING:Model Compression Toolkit:Pytorch model has a parameter or constant Tensor value. This can cause unexpected behaviour when converting the model.
# ERROR:Model Compression Toolkit:Found duplicate qco types!
# ERROR:Model Compression Toolkit:Found duplicate qco types!
# ERROR:Model Compression Toolkit:Found duplicate qco types!
# ERROR:Model Compression Toolkit:Found duplicate qco types!
# ERROR:Model Compression Toolkit:Found duplicate qco types!
# ERROR:Model Compression Toolkit:Found duplicate qco types!
# ERROR:Model Compression Toolkit:Found duplicate qco types!
# ERROR:Model Compression Toolkit:Found duplicate qco types!
# ERROR:Model Compression Toolkit:Found duplicate qco types!
# representative_data_gen generates a batch size of 1 which can be slow for optimization: consider increasing the batch size
# Pytorch model has a parameter or constant Tensor value. This can cause unexpected behaviour when converting the model.
# Pytorch model has a parameter or constant Tensor value. This can cause unexpected behaviour when converting the model.
# Pytorch model has a parameter or constant Tensor value. This can cause unexpected behaviour when converting the model.
# Pytorch model has a parameter or constant Tensor value. This can cause unexpected behaviour when converting the model.
# Pytorch model has a parameter or constant Tensor value. This can cause unexpected behaviour when converting the model.
# Mixed precision enabled.
# WARNING:Model Compression Toolkit:Pytorch model has a parameter or constant Tensor value. This can cause unexpected behaviour when converting the model.
# WARNING:Model Compression Toolkit:Pytorch model has a parameter or constant Tensor value. This can cause unexpected behaviour when converting the model.
# WARNING:Model Compression Toolkit:Pytorch model has a parameter or constant Tensor value. This can cause unexpected behaviour when converting the model.
# WARNING:Model Compression Toolkit:Pytorch model has a parameter or constant Tensor value. This can cause unexpected behaviour when converting the model.
# WARNING:Model Compression Toolkit:Pytorch model has a parameter or constant Tensor value. This can cause unexpected behaviour when converting the model.
# ERROR:Model Compression Toolkit:Found duplicate qco types!
# ERROR:Model Compression Toolkit:Found duplicate qco types!
# ERROR:Model Compression Toolkit:Found duplicate qco types!
# ERROR:Model Compression Toolkit:Found duplicate qco types!
# ERROR:Model Compression Toolkit:Found duplicate qco types!
# ERROR:Model Compression Toolkit:Found duplicate qco types!
# ERROR:Model Compression Toolkit:Found duplicate qco types!
# ERROR:Model Compression Toolkit:Found duplicate qco types!
# ERROR:Model Compression Toolkit:Found duplicate qco types!
# Pytorch model has a parameter or constant Tensor value. This can cause unexpected behaviour when converting the model.
# Pytorch model has a parameter or constant Tensor value. This can cause unexpected behaviour when converting the model.
# Pytorch model has a parameter or constant Tensor value. This can cause unexpected behaviour when converting the model.
# Pytorch model has a parameter or constant Tensor value. This can cause unexpected behaviour when converting the model.
# Pytorch model has a parameter or constant Tensor value. This can cause unexpected behaviour when converting the model.
# Statistics Collection: 4it [00:01,  3.62it/s]
# Running quantization parameters search. This process might take some time, depending on the model size and the selected quantization methods.
# Calculating quantization parameters: 100%|██████████| 194/194 [00:24<00:00,  7.86it/s]
# WARNING:Model Compression Toolkit:Not enough images in representative dataset to generate 10 data points, only 4 were generated
# Not enough images in representative dataset to generate 10 data points, only 4 were generated
# Starting to evaluate metrics
# 100%|██████████| 64/64 [00:50<00:00,  1.27it/s]
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/user/proj/imx500/venvBuildImx500/lib/python3.11/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/438e4b5486c64e8c96b24cb2c9908459-pulp.mps -sec 60 -timeMode elapsed -branch -printingOptions all -solution /tmp/438e4b5486c64e8c96b24cb2c9908459-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 134 COLUMNS
# At line 1159 RHS
# At line 1289 BOUNDS
# At line 1482 ENDATA
# Problem MODEL has 129 rows, 256 columns and 576 elements
# Coin0008I MODEL read with 0 errors
# seconds was changed from 1e+100 to 60
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 0.293375 - 0.00 seconds
# Cgl0004I processed model has 65 rows, 192 columns (192 integer (192 of which binary)) and 320 elements
# Cbc0038I Initial state - 2 integers unsatisfied sum - 0.829583
# Cbc0038I Solution found of 0.294348
# Cbc0038I Before mini branch and bound, 190 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 65 rows 192 columns, reduced to 0 rows 0 columns
# Cbc0038I Mini branch and bound did not improve solution (0.01 seconds)
# Cbc0038I Round again with cutoff of 0.294242
# Cbc0038I Reduced cost fixing fixed 104 variables on major pass 2
# Cbc0038I Pass   1: suminf.    0.05310 (2) obj. 0.294242 iterations 3
# Cbc0038I Pass   2: suminf.    0.41479 (2) obj. 0.293517 iterations 3
# Cbc0038I Pass   3: suminf.    0.94069 (2) obj. 0.293513 iterations 5
# Cbc0038I Pass   4: suminf.    0.18729 (2) obj. 0.294242 iterations 2
# Cbc0038I Pass   5: suminf.    0.47035 (2) obj. 0.293675 iterations 3
# Cbc0038I Pass   6: suminf.    1.40606 (4) obj. 0.294242 iterations 10
# Cbc0038I Pass   7: suminf.    1.16234 (4) obj. 0.294242 iterations 2
# Cbc0038I Pass   8: suminf.    0.55931 (2) obj. 0.293713 iterations 3
# Cbc0038I Pass   9: suminf.    0.58003 (2) obj. 0.294242 iterations 4
# Cbc0038I Pass  10: suminf.    0.72035 (2) obj. 0.293961 iterations 3
# Cbc0038I Pass  11: suminf.    1.46017 (4) obj. 0.294242 iterations 3
# Cbc0038I Pass  12: suminf.    1.34888 (4) obj. 0.294242 iterations 3
# Cbc0038I Pass  13: suminf.    0.11486 (2) obj. 0.294057 iterations 3
# Cbc0038I Pass  14: suminf.    0.11486 (2) obj. 0.294057 iterations 0
# Cbc0038I Pass  15: suminf.    1.08297 (4) obj. 0.294242 iterations 9
# Cbc0038I Pass  16: suminf.    0.95450 (4) obj. 0.294242 iterations 1
# Cbc0038I Pass  17: suminf.    0.25722 (2) obj. 0.293962 iterations 4
# Cbc0038I Pass  18: suminf.    0.25722 (2) obj. 0.293962 iterations 0
# Cbc0038I Pass  19: suminf.    0.92960 (4) obj. 0.294242 iterations 3
# Cbc0038I Pass  20: suminf.    1.10782 (4) obj. 0.294242 iterations 1
# Cbc0038I Pass  21: suminf.    1.10782 (4) obj. 0.294242 iterations 0
# Cbc0038I Pass  22: suminf.    0.20167 (2) obj. 0.294004 iterations 3
# Cbc0038I Pass  23: suminf.    0.20167 (2) obj. 0.294004 iterations 0
# Cbc0038I Pass  24: suminf.    1.07616 (4) obj. 0.294242 iterations 6
# Cbc0038I Pass  25: suminf.    0.69246 (4) obj. 0.294242 iterations 4
# Cbc0038I Pass  26: suminf.    0.70167 (2) obj. 0.293672 iterations 3
# Cbc0038I Pass  27: suminf.    0.70167 (2) obj. 0.293672 iterations 0
# Cbc0038I Pass  28: suminf.    0.47603 (2) obj. 0.294242 iterations 3
# Cbc0038I Pass  29: suminf.    0.64917 (2) obj. 0.293895 iterations 2
# Cbc0038I Pass  30: suminf.    1.72560 (4) obj. 0.294242 iterations 5
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 168 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 65 rows 192 columns, reduced to 1 rows 12 columns
# Cbc0038I Mini branch and bound improved solution from 0.294348 to 0.293707 (0.01 seconds)
# Cbc0038I Round again with cutoff of 0.293632
# Cbc0038I Reduced cost fixing fixed 114 variables on major pass 3
# Cbc0038I Pass  30: suminf.    0.61003 (2) obj. 0.293632 iterations 1
# Cbc0038I Pass  31: suminf.    0.82958 (2) obj. 0.293375 iterations 9
# Cbc0038I Pass  32: suminf.    1.18764 (4) obj. 0.293632 iterations 3
# Cbc0038I Pass  33: suminf.    0.63927 (4) obj. 0.293632 iterations 1
# Cbc0038I Pass  34: suminf.    0.74278 (2) obj. 0.29345 iterations 1
# Cbc0038I Pass  35: suminf.    0.58776 (2) obj. 0.293632 iterations 1
# Cbc0038I Pass  36: suminf.    0.09843 (2) obj. 0.293632 iterations 2
# Cbc0038I Solution found of 0.293627
# Cbc0038I Before mini branch and bound, 182 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 65 rows 192 columns, reduced to 1 rows 3 columns
# Cbc0038I Mini branch and bound did not improve solution (0.01 seconds)
# Cbc0038I Round again with cutoff of 0.293544
# Cbc0038I Reduced cost fixing fixed 117 variables on major pass 4
# Cbc0038I Pass  37: suminf.    0.68502 (2) obj. 0.293544 iterations 0
# Cbc0038I Pass  38: suminf.    0.82958 (2) obj. 0.293375 iterations 9
# Cbc0038I Pass  39: suminf.    0.45498 (4) obj. 0.293544 iterations 3
# Cbc0038I Pass  40: suminf.    0.45498 (4) obj. 0.293544 iterations 0
# Cbc0038I Pass  41: suminf.    0.32910 (2) obj. 0.293544 iterations 1
# Cbc0038I Pass  42: suminf.    0.25722 (2) obj. 0.29346 iterations 1
# Cbc0038I Pass  43: suminf.    0.25722 (2) obj. 0.29346 iterations 0
# Cbc0038I Pass  44: suminf.    0.25722 (2) obj. 0.29346 iterations 0
# Cbc0038I Pass  45: suminf.    0.25722 (2) obj. 0.29346 iterations 1
# Cbc0038I Pass  46: suminf.    1.39578 (4) obj. 0.293544 iterations 2
# Cbc0038I Pass  47: suminf.    1.38621 (4) obj. 0.293544 iterations 1
# Cbc0038I Pass  48: suminf.    0.49625 (2) obj. 0.293504 iterations 1
# Cbc0038I Pass  49: suminf.    0.46192 (2) obj. 0.293544 iterations 1
# Cbc0038I Pass  50: suminf.    0.73885 (4) obj. 0.293544 iterations 5
# Cbc0038I Pass  51: suminf.    0.19313 (2) obj. 0.293531 iterations 1
# Cbc0038I Pass  52: suminf.    0.89909 (2) obj. 0.293544 iterations 2
# Cbc0038I Pass  53: suminf.    0.79542 (2) obj. 0.293423 iterations 1
# Cbc0038I Pass  54: suminf.    0.79542 (2) obj. 0.293423 iterations 1
# Cbc0038I Pass  55: suminf.    0.79542 (2) obj. 0.293423 iterations 0
# Cbc0038I Pass  56: suminf.    0.68431 (2) obj. 0.293526 iterations 3
# Cbc0038I Pass  57: suminf.    0.68431 (2) obj. 0.293526 iterations 0
# Cbc0038I Pass  58: suminf.    0.70011 (2) obj. 0.293544 iterations 1
# Cbc0038I Pass  59: suminf.    0.76156 (2) obj. 0.293544 iterations 4
# Cbc0038I Pass  60: suminf.    0.73986 (2) obj. 0.293519 iterations 1
# Cbc0038I Pass  61: suminf.    0.76156 (2) obj. 0.293544 iterations 1
# Cbc0038I Pass  62: suminf.    1.76938 (4) obj. 0.293544 iterations 3
# Cbc0038I Pass  63: suminf.    1.76938 (4) obj. 0.293544 iterations 0
# Cbc0038I Pass  64: suminf.    0.91976 (2) obj. 0.293544 iterations 1
# Cbc0038I Pass  65: suminf.    0.88222 (2) obj. 0.2935 iterations 1
# Cbc0038I Pass  66: suminf.    0.79542 (2) obj. 0.293423 iterations 1
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 174 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 65 rows 192 columns, reduced to 1 rows 8 columns
# Cbc0038I Mini branch and bound improved solution from 0.293627 to 0.293603 (0.01 seconds)
# Cbc0038I Round again with cutoff of 0.293493
# Cbc0038I Reduced cost fixing fixed 117 variables on major pass 5
# Cbc0038I Pass  66: suminf.    0.72839 (2) obj. 0.293493 iterations 0
# Cbc0038I Pass  67: suminf.    0.82958 (2) obj. 0.293375 iterations 9
# Cbc0038I Pass  68: suminf.    1.08347 (4) obj. 0.293493 iterations 3
# Cbc0038I Pass  69: suminf.    1.08347 (4) obj. 0.293493 iterations 0
# Cbc0038I Pass  70: suminf.    0.15599 (2) obj. 0.293493 iterations 1
# Cbc0038I Pass  71: suminf.    0.11486 (2) obj. 0.293445 iterations 1
# Cbc0038I Pass  72: suminf.    0.52920 (4) obj. 0.293493 iterations 2
# Cbc0038I Pass  73: suminf.    0.11486 (2) obj. 0.29348 iterations 1
# Cbc0038I Pass  74: suminf.    0.12592 (2) obj. 0.293493 iterations 1
# Cbc0038I Pass  75: suminf.    0.12592 (2) obj. 0.293493 iterations 0
# Cbc0038I Pass  76: suminf.    0.71292 (4) obj. 0.293493 iterations 2
# Cbc0038I Pass  77: suminf.    0.52543 (4) obj. 0.293493 iterations 3
# Cbc0038I Pass  78: suminf.    0.20167 (2) obj. 0.293481 iterations 1
# Cbc0038I Pass  79: suminf.    0.21193 (2) obj. 0.293493 iterations 1
# Cbc0038I Pass  80: suminf.    1.55525 (4) obj. 0.293493 iterations 3
# Cbc0038I Pass  81: suminf.    0.62011 (2) obj. 0.293493 iterations 1
# Cbc0038I Pass  82: suminf.    0.65597 (2) obj. 0.293451 iterations 1
# Cbc0038I Pass  83: suminf.    0.34403 (2) obj. 0.293461 iterations 5
# Cbc0038I Pass  84: suminf.    0.34403 (2) obj. 0.293461 iterations 0
# Cbc0038I Pass  85: suminf.    0.37173 (2) obj. 0.293493 iterations 1
# Cbc0038I Pass  86: suminf.    1.18803 (4) obj. 0.293493 iterations 4
# Cbc0038I Pass  87: suminf.    0.25722 (2) obj. 0.29346 iterations 1
# Cbc0038I Pass  88: suminf.    0.28573 (2) obj. 0.293493 iterations 1
# Cbc0038I Pass  89: suminf.    0.25722 (2) obj. 0.29346 iterations 3
# Cbc0038I Pass  90: suminf.    0.28573 (2) obj. 0.293493 iterations 1
# Cbc0038I Pass  91: suminf.    0.17020 (2) obj. 0.293487 iterations 4
# Cbc0038I Pass  92: suminf.    0.17020 (2) obj. 0.293487 iterations 0
# Cbc0038I Pass  93: suminf.    0.17569 (2) obj. 0.293493 iterations 1
# Cbc0038I Pass  94: suminf.    0.71947 (4) obj. 0.293493 iterations 3
# Cbc0038I Pass  95: suminf.    0.46371 (4) obj. 0.293493 iterations 1
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 172 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 65 rows 192 columns, reduced to 1 rows 9 columns
# Cbc0038I Mini branch and bound did not improve solution (0.02 seconds)
# Cbc0038I After 0.02 seconds - Feasibility pump exiting with objective of 0.293603 - took 0.01 seconds
# Cbc0012I Integer solution of 0.29360265 found by feasibility pump after 0 iterations and 0 nodes (0.02 seconds)
# Cbc0012I Integer solution of 0.29352599 found by DiveCoefficient after 0 iterations and 0 nodes (0.02 seconds)
# Cbc0031I 3 added rows had average density of 12.333333
# Cbc0013I At root node, 11 cuts changed objective from 0.29337458 to 0.29351967 in 2 passes
# Cbc0014I Cut generator 0 (Probing) - 4 row cuts average 2.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 2 (Knapsack) - 3 row cuts average 4.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 12 row cuts average 15.5 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0001I Search completed - best objective 0.2935259872312899, took 6 iterations and 0 nodes (0.02 seconds)
# Cbc0035I Maximum depth 0, 119 variables fixed on reduced cost
# Cuts at root node changed objective from 0.293375 to 0.29352
# Probing was tried 2 times and created 4 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 2 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 2 times and created 3 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 2 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 2 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 2 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 2 times and created 12 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                0.29352599
# Enumerated nodes:               0
# Total iterations:               6
# Time (CPU seconds):             0.02
# Time (Wallclock seconds):       0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Optimal
# Final weights bit-width configuration: [8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 4, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 4, 8, 8, 8, 8, 8, 8, 4, 8, 4, 4, 4, 8, 8, 4, 4, 4, 4, 4, 4, 4, 4, 8, 8, 8]
#
# Please run your accuracy evaluation on the exported quantized model to verify it's accuracy.
# Checkout the FAQ and Troubleshooting pages for resolving common issues and improving the quantized model accuracy:
# FAQ: https://github.com/sony/model_optimization/tree/main/FAQ.md
# Quantization Troubleshooting: https://github.com/sony/model_optimization/tree/main/quantization_troubleshooting.md
# Exporting onnx model with MCTQ quantizers: yolov8n_imx_model/yolov8n_imx.onnx
# 2025-03-04 03:58:30,791 INFO : Running version 1.10.0 [/home/user/proj/imx500/venvBuildImx500/lib/python3.11/site-packages/uni/common/logger.py:148]
# 2025-03-04 03:58:30,791 INFO : Converting yolov8n_imx_model/yolov8n_imx.onnx [/home/user/proj/imx500/venvBuildImx500/lib/python3.11/site-packages/uni/common/logger.py:148]
# 2025-03-04 03:58:38,979 INFO : Wrote outputs to /tmp/tmphlh7ux7z/yolov8n_imx.uni-pytorch.um.pb [/home/user/proj/imx500/venvBuildImx500/lib/python3.11/site-packages/uni/common/logger.py:148]
# 2025-03-04 03:58:38,994 INFO : Converted successfully [/home/user/proj/imx500/venvBuildImx500/lib/python3.11/site-packages/uni/common/logger.py:148]
# 2025-03-04 03:58:39,544 INFO : CODE: [START] Starting SDSPconv
# 2025-03-04 03:59:16,332 INFO : ConvFe conversion finished successfully
# 2025-03-04 03:59:16,837 INFO : CBE component - DspConvParser has started conversion.
# 2025-03-04 03:59:17,041 INFO : Dsp-Dnn-Parser finished successfully !
# 2025-03-04 03:59:18,325 INFO : LogicModel generated successfully !
# 2025-03-04 03:59:18,325 INFO : LogicModel path is: /home/user/proj/imx500/myKM_readONLY/packDemo2/yolov8n_imx_model/tempConverterFm2Lm/yolov8n_imx
# 2025-03-04 03:59:18,327 INFO : DspConvParser runs: 1503 [msec]
# 2025-03-04 03:59:18,327 INFO : CBE component - DspConvParser finished conversion.
# 2025-03-04 04:00:03,255 INFO : Converter Backend successfully completed!
# 2025-03-04 04:00:03,256 INFO : Conversion time is 44.84 Seconds
# 2025-03-04 04:00:03,848 INFO : packer zip successfully generated under /home/user/proj/imx500/myKM_readONLY/packDemo2/yolov8n_imx_model/packerOut.zip
# 2025-03-04 04:00:03,870 INFO : CODE: [OUTPUT] Output is in /home/user/proj/imx500/myKM_readONLY/packDemo2/yolov8n_imx_model
# 2025-03-04 04:00:03,890 INFO : CODE: [DONE] Done (1m 24s)
# IMX: export success ✅ 181.3s, saved as 'yolov8n_imx_model' (14.5 MB)
#
# Export complete (181.6s)
# Results saved to /home/user/proj/imx500/myKM_readONLY/packDemo2
# Predict:         yolo predict task=detect model=yolov8n_imx_model imgsz=640 int8
# Validate:        yolo val task=detect model=yolov8n_imx_model imgsz=640 data=coco.yaml int8
# Visualize:       https://netron.app
# 'yolov8n_imx_model'

# %% [markdown]
# ## test

# %%
test_url = 'https://www.ultralytics.com/images/bus.jpg'

# %%
## show image
import requests
from PIL import Image
from io import BytesIO
import matplotlib.pyplot as plt
# Fetch the image via HTTP GET
response = requests.get(test_url)
# Open the image from the downloaded bytes
img = Image.open(BytesIO(response.content))
# Display using matplotlib
plt.imshow(img)
plt.axis('off')  # Hide axis labels
plt.show()

# %%
# Load the exported model
imx_model = YOLO("yolov8n_imx_model")

# Run inference
results = imx_model(test_url)
# Out:
# WARNING ⚠️ Unable to automatically guess model task, assuming 'task=detect'. Explicitly define task for your model, i.e. 'task=detect', 'segment', 'classify','pose' or 'obb'.
# Loading yolov8n_imx_model for ONNX Runtime inference...
# Using ONNX Runtime CPUExecutionProvider
# Loading yolov8n_imx_model/yolov8n_imx.onnx for ONNX IMX inference...
#
# Found https://www.ultralytics.com/images/bus.jpg locally at bus.jpg
# image 1/1 /home/user/proj/imx500/myKM_readONLY/packDemo2/bus.jpg: 640x640 4 persons, 1 bus, 1930.3ms
# Speed: 1.6ms preprocess, 1930.3ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 640)

# %%
# 3. Display bounding boxes on image
annotated_image = results[0].plot()

# 4. (Optional) Show in notebook
import matplotlib.pyplot as plt

plt.imshow(annotated_image)
plt.axis("off")
plt.show()
